# %%
import pandas as pd
import re
use_cases = re.compile('use.cases|use.case', re.IGNORECASE)
object_re = re.compile("object.diagram", re.IGNORECASE)

# %%
file_types = pd.read_csv("./db/Project_FileTypes_V2.0.csv")
uml_files = pd.read_csv("./db/UMLFiles_List_V2.0.csv")

# %%
pd.set_option('display.max_colwidth', None)
use_cases_df = uml_files[uml_files['Model Link - Github'].str.contains(use_cases)==True]['Model Link - Github']
uml_files[uml_files['Model Link - Github'].str.contains(use_cases)==True]
# Out:
#                                Project  \
# 11                  09421/Track-A-Bus/
# 15                  09421/Track-A-Bus/
# 16                  09421/Track-A-Bus/
# 17                  09421/Track-A-Bus/
# 18                  09421/Track-A-Bus/
# ...                                ...
# 93188              zThorn/Victus-Docs/
# 93356          AndreaL93/swe2-project/
# 93357          AndreaL93/swe2-project/
# 93447  jcechak/pokemon-league-manager/
# 93545         printminion/mkPhpSurvey/
#
#                                                                                                                                                            Model Link - Github
# 11                                            https://www.github.com/09421/Track-A-Bus/tree/master/1 - Systemdesign/1 - Ikke-samlede docs/Diagrammer/Misc/Use_Case_Diagram.jpg
# 15                                               https://www.github.com/09421/Track-A-Bus/tree/master/1 - Systemdesign/3 - 4th/04_Systemdesign/Diagrammer/Use_Case_Diagram.jpg
# 16                                             https://www.github.com/09421/Track-A-Bus/tree/master/2 - Kravspec/2 - Samlet kravspec/Use_Cases/Diagrammer/Use_Case_Diagram.jpg
# 17                                                                   https://www.github.com/09421/Track-A-Bus/tree/master/4 - Rapport/4 semester/Billeder/Use_Case_Diagram.jpg
# 18                                                                              https://www.github.com/09421/Track-A-Bus/tree/master/4 - Rapport/Billeder/Use_Case_Diagram.jpg
# ...                                                                                                                                                                        ...
# 93188                                                     https://www.github.com/zThorn/Victus-Docs/tree/master/Docs and Resources/Sprint 1/Use Case (Game Menu) Diagram 1.png
# 93356  https://www.github.com/AndreaL93/swe2-project/tree/master/Working directory/RASD/Use_cases_and_Sequence_diagram/SequenceDiagrams svg/svg/Model1__UseCaseDiagram1_17.svg
# 93357    https://www.github.com/AndreaL93/swe2-project/tree/master/Working directory/RASD/Use_cases_and_Sequence_diagram/SequenceDiagrams svg/svg/Model2__ClassDiagram1_20.svg
# 93447                                                                          https://www.github.com/jcechak/pokemon-league-manager/tree/master/diagrams/use_case_diagram.svg
# 93545                                                                           https://www.github.com/printminion/mkPhpSurvey/tree/master/_documentation/Use_Case_Diagram.svg
#
# [1365 rows x 2 columns]

# %%
get_user = re.compile("^https:\/\/www\.github\.com\/([a-zA-Z0-9_-]+)\/")
users = []
BOLD = '\033[1m'
END = '\033[0m'
count = 0
print(BOLD+"Unique users:\n"+END)
for link in use_cases_df:
    s = re.search(get_user, link)
    user = s.group(1)
    if user in users:
        continue
    else:
        users.append(user)
        count+=1
        if count > 10 and count < 550:
            if count == 11:
                print("...\n")
        else:
            print(f'{count}.\t{link.replace(" ", "%20")}\n')
print(BOLD + f'\n{count} unique users' + END)
# Out:
# Unique users:
#
# 1.	https://www.github.com/09421/Track-A-Bus/tree/master/1%20-%20Systemdesign/1%20-%20Ikke-samlede%20docs/Diagrammer/Misc/Use_Case_Diagram.jpg
#
# 2.	https://www.github.com/188383/project/tree/master/uml/use%20case%20diagram.jpeg
#
# 3.	https://www.github.com/abdurrohimfajar5/inginreposit/tree/master/Use%20Case%20Diagram.jpg
#
# 4.	https://www.github.com/AbeOmor/WebHandyTool/tree/master/Documentation/images/pylinkvalidator_Use_Case_Diagram.png
#
# 5.	https://www.github.com/abhisek-agrawal/UCMS-project/tree/master/UCMS-use-case-diagram.jpg
#
# 6.	https://www.github.com/ACalitz/COS301Phase1Group1A/tree/master/Images/Authentication__Use_Case_Diagram.png
#
# 7.	https://www.github.com/Acilyn/SyntaxError/tree/master/DeadLine_7_17_2015/Figure%201-1_%20Use-Case%20Diagram%20.jpg
#
# 8.	https://www.github.com/adesuk/lavender/tree/master/Laporan%20Dokumentasi/Use%20Case%20Penjadwalan%20Karya%20Akhir.uml
#
# 9.	https://www.github.com/adnammit/Tudu/tree/master/documentation/Tudu%20Use%20Case%20Diagram.png
#
# 10.	https://www.github.com/Adwelean/ppe_formation/tree/master/Ressources/20141212_Use_Case_Diagram.png
#
# ...
#
# 550.	https://www.github.com/ZaneUram/EE491/tree/master/Game%20Control%20Panel/UML%20Diagrams/Use%20Case%20Diagram%20Version%201.jpg
#
# 551.	https://www.github.com/zatcsc/group5.k57ca/tree/master/UML/Use%20Case%20Diagram.png
#
# 552.	https://www.github.com/Zedyz/Gruppe10/tree/master/Marthe/Use%20case-diagramOppretteBruker.png
#
# 553.	https://www.github.com/zhxnlai/TicketsTonight/tree/master/Requirement%20Document/basic_use_case_diagram.png
#
# 554.	https://www.github.com/zThorn/Victus-Docs/tree/master/Docs%20and%20Resources/Sprint%201/Use%20Case%20(Game%20Menu)%20Diagram%201.png
#
# 555.	https://www.github.com/AndreaL93/swe2-project/tree/master/Working%20directory/RASD/Use_cases_and_Sequence_diagram/SequenceDiagrams%20svg/svg/Model1__UseCaseDiagram1_17.svg
#
# 556.	https://www.github.com/printminion/mkPhpSurvey/tree/master/_documentation/Use_Case_Diagram.svg
#
#
# 556 unique users
